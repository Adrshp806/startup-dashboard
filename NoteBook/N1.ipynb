# %%
import numpy as np
import pandas as pd
import os 
import pathlib as path

# %%
# %pwd
# Out:
# 'd:\\python\\startup-dashboard\\NoteBook'

# %%
df = pd.read_csv('D:\python\startup-dashboard\startup_funding.csv' , index_col='Sr No')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\adiip\AppData\Local\Temp\ipykernel_7404\2004398131.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('D:\python\startup-dashboard\startup_funding.csv' , index_col='Sr No')

# %%
df
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
# ...               ...                           ...                  ...
# 3040       29/01/2015                    Printvenue                  NaN
# 3041       29/01/2015                      Graphene                  NaN
# 3042       30/01/2015                Mad Street Den                  NaN
# 3043       30/01/2015                     Simplotel                  NaN
# 3044       31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical City  Location  \
# Sr No
# ...

# %%
df['Startup Name'].unique().tolist()
# Out:
# ['BYJU’S',
#  'Shuttl',
#  'Mamaearth',
#  'https://www.wealthbucket.in/',
#  'Fashor',
#  'Pando',
#  'Zomato',
#  'Ecozen',
#  'CarDekho',
#  'Dhruva Space',
#  'Rivigo',
#  'Healthians',
#  'Licious',
#  'InCred',
#  'Trell',
#  'Rein Games',
#  'Lenskart.com',
#  'Freshworks',
#  'Misters',
#  'Sunstone Eduversity Pvt. Ltd',
#  'Burger Singh',
#  'Ninjacart',
#  'Aye Finance',
#  'SuperGaming',
#  'Clumio',
#  'eBikeGo',
#  'Digital Mall Asia',
#  'Medikabazaar',
#  'Vogo Automotive',
#  'Furtados School of Music',
#  'Paytm',
#  'Dunzo',
#  'Udaan',
#  'The Man Company',
#  'FPL Technologies',
#  'Cashflo',
#  'Digital F5',
#  '3rdFlix',
#  '75F',
#  'Myelin Foundry',
#  'Atomberg Technology',
#  'GOQii',
#  'Vyapar App',
#  'Progcap',
#  'MyPetrolPump',
#  'Alteria Capital',
#  'Pine Labs',
#  'Meesho',
#  'Cars24',
#  'Uniphore',
#  'Zendrive',
#  'Lo! Foods',
#  'Tala',
#  'INDwealth',
#  'HungerBox',
#  'AdmitKard',
#  'Mishry Reviews',
#  'Grofers',
#  'Rapido Bike Taxi',
# ...

# %%
df['Investors Name'].unique().tolist()
# Out:
# ['Tiger Global Management',
#  'Susquehanna Growth Equity',
#  'Sequoia Capital India',
#  'Vinod Khatumal',
#  'Sprout Venture Partners',
#  'Chiratae Ventures',
#  'Ant Financial',
#  'Sathguru Catalyzer Advisors',
#  'Ping An Global Voyager Fund',
#  'Mumbai Angels, Ravikanth Reddy',
#  'SAIF Partners, Spring Canter Investment Ltd.',
#  'Paytm, NPTK, Sabre Partners and Neoplux',
#  'Vertex Growth Fund',
#  nan,
#  'Ruizheng Investment',
#  'Manipal Education and Medical Group (MEMG)',
#  'SoftBank Vision Fund',
#  'Sequoia, CapitalG, Accel',
#  'Sauce.vc, Rainforest Ventures',
#  'Prime Venture Partners, LetsVenture, PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  'RB Investments',
#  'DG Daiwa Ventures, DG Incubation',
#  'Trifecta Capital Advisors',
#  'FinTech',
#  'Dream Incubator',
#  'Altimeter Capital, Sutter Hill Ventures',
#  'Startup Buddy',
#  'Amour Infrastructure',
#  'Ackermans & van Haaren, HealthQuad, Rebright Partners, Toppan Printing',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date dd/mm/yyyy    3044 non-null   object
#  1   Startup Name       3044 non-null   object
#  2   Industry Vertical  2873 non-null   object
#  3   SubVertical        2108 non-null   object
#  4   City  Location     2864 non-null   object
#  5   Investors Name     3020 non-null   object
#  6   InvestmentnType    3040 non-null   object
#  7   Amount in USD      2084 non-null   object
#  8   Remarks            419 non-null    object
# dtypes: object(9)
# memory usage: 237.8+ KB

# %%
df['Investors Name'] = df['Investors Name'].fillna('Undisclosed')

# %%
sorted(df['Investors Name'].unique().tolist())
# Out:
# ['"Kedaraa Capital, Ontario Teachers\\\\\'"',
#  '021 Capita, Binny Bansal',
#  '1Crowd',
#  '1Crowd (through crowd funding)',
#  '1Crowd (through crowdfunding)',
#  '1Crowd, Ankur Capital',
#  '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.',
#  '3 undisclosed HNIs',
#  '3 undisclosed investors',
#  '3One4 Capital',
#  '3one4 Capital, Mumbai Angels, Aarin Capital',
#  '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners',
#  '3one4 capital',
#  '500 Startups',
#  '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave',
#  '500 Startups, IvyCap Ventures',
#  '500 Startups, Littlerock, Singularity Ventures',
#  '500 Startups, Mato Peric & Others',
#  '500 Startups, Mato Peric, TracxnLabs',
#  '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta',
#  '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham',
#  '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai',
#  '50K Ventures',
# ...

# %%
df.head()
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
#
#                                  SubVertical City  Location  \
# Sr No
# 1                                 E-learning      Bengaluru
# 2                  App based shuttle service        Gurgaon
# 3      Retailer of baby and toddler products      Bengaluru
# 4                          Online Investment      New Delhi
# 5                Embroiled Clothes For Women         Mumbai
#
#                   Investors Name       InvestmentnType Amount in USD Remarks
# Sr No
# ...

# %%
#drop the 'Remarks' column as it contains no useful information for our analysis
df.drop(columns=['Remarks'], inplace=True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy': 'date',
    'Startup Name': 'startup',
    'Industry Vertical': 'vertical',
    'Subvertical': 'subvertical',
    'City  Location': 'city',
    'InvestmentnType': 'round',
    'Investors Name': 'investors',
    'Amount in USD': 'amount',


}, inplace=True)

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
#need to convert amount to cr Rupess
#1. we need to convert into float 
df['amount'] = df['amount'].fillna('0')

# %%
df['amount']=df['amount'].str.replace(',','')

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df['amount']=df['amount'].str.replace('undisclosed','0')
df['amount']=df['amount'].str.replace('unknown','0')
df['amount']=df['amount'].str.replace('Undisclosed','0')

# %%
df = df[df['amount'].str.isdigit()]

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df['amount'] = df['amount'].astype(float)
# Out:
# C:\Users\adiip\AppData\Local\Temp\ipykernel_7404\1060450643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount'] = df['amount'].astype(float)

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3029 non-null   object
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   SubVertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3029 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 213.0+ KB

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  SubVertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000.0
# ...

# %%
def to_inr(dollar):
    inr = dollar *82.5
    return inr/10000000

# %%
to_inr(1000000)
# Out:
# 8.25

# %%
df['amount']=df['amount'].apply(to_inr)
# Out:
# C:\Users\adiip\AppData\Local\Temp\ipykernel_7404\4236546661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].apply(to_inr)

# %%
#date column need to convert to datetime format
df['date'] = pd.to_datetime(df['date'],format='mixed', errors='coerce')
# Out:
# C:\Users\adiip\AppData\Local\Temp\ipykernel_7404\112500478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'],format='mixed', errors='coerce')

# %%
df
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                  NaN
# 3041  2015-01-29                      Graphene                  NaN
# 3042  2015-01-30                Mad Street Den                  NaN
# 3043  2015-01-30                     Simplotel                  NaN
# 3044  2015-01-31              couponmachine.in                  NaN
#
#                                  SubVertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df = df.dropna(subset=['amount','date','startup','vertical','city','round','investors'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2845 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2845 non-null   datetime64[ns]
#  1   startup      2845 non-null   object
#  2   vertical     2845 non-null   object
#  3   SubVertical  2095 non-null   object
#  4   city         2845 non-null   object
#  5   investors    2845 non-null   object
#  6   round        2845 non-null   object
#  7   amount       2845 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 200.0+ KB

# %%
df
# Out:
#             date                       startup                    vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  SubVertical       city  \
# ...

# %%
df.to_csv('startup_funding_cleaned.csv')
